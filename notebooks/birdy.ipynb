# %%
from birdy import WPSClient

# %%
clint = WPSClient("http://136.172.60.99:5000/wps")

# %%
resp = clint.crai(
    dataset_name="HadCRUT4", 
    variable_name="temperature_anomaly",
    # variable_name="tas_mean",
    file="https://www.metoffice.gov.uk/hadobs/hadcrut4/data/current/gridded_fields/HadCRUT.4.6.0.0.median_netcdf.zip"
    #file="https://www.metoffice.gov.uk/hadobs/hadcrut5/data/current/non-infilled/HadCRUT.5.0.1.0.anomalies.ensemble_mean.nc"
)

# %%
prov_plot_url = resp.get()[3]
print(prov_plot_url)
# Out:
# http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/provenance.png

# %%
from IPython.display import Image
Image(prov_plot_url)

# %%
info_url = resp.get()[4]
print(info_url)
# Out:
# http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/info.txt

# %%
Attrs:
  Conventions: CF-1.0
  comment: ''
  history: Updated at 28/02/2022 11:21:55
  institution: Met Office Hadley Centre / Climatic Research Unit, University of East
    Anglia
  reference: 'Morice, C. P., J. J. Kennedy, N. A. Rayner, and P. D. Jones (2012),
    Quantifying uncertainties in global and regional temperature change using an ensemble
    of observational estimates: The HadCRUT4 dataset, J. Geophys. Res., doi:10.1029/2011JD017187'
  source: CRUTEM.4.6.0.0, HadSST.3.1.1.0
  title: HadCRUT4 near-surface temperature ensemble data - ensemble median
  version: HadCRUT.4.6.0.0
Dims:
  latitude: 36
  longitude: 72
  time: 2064
Mstats:
  max: 0.9035493827160493
  mean: 0.514733953308929
  min: 0.2222222222222222
  std: 0.19611201774956183
Vars:
- latitude
- longitude
- time
- temperature_anomaly
- field_status
Vstats:
  max: 20.62030792236328
  mean: 0.034507300704717636
  min: -20.84668731689453
  std: 1.4045873880386353

# %%
hist_url = resp.get()[5]
print(hist_url)
# Out:
# http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/histime.png

# %%
from IPython.display import Image
Image(hist_url)

# %%
resp.get()
# Out:
# craiResponse(
#     output='http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/HadCRUT.4.6.0.0.median_netcdf_infilled.zip',
#     plot='http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/HadCRUT.4.6.0.0.median_combined.1_0.png',
#     prov='http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/provenance.json',
#     prov_plot='http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/provenance.png',
#     info='http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/info.txt',
#     hist='http://smartduck.dkrz.de:5000/outputs/db1db828-f014-11ed-ad95-fa163e38a856/histime.png'
# )
