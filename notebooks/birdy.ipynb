# %%
from birdy import WPSClient

# %%
clint = WPSClient("http://localhost:5000/wps")

# %%
# clint.crai?

# %%
resp = clint.crai(
    dataset_name="HadCRUT5", 
    variable_name="tas_mean", 
    file="https://www.metoffice.gov.uk/hadobs/hadcrut5/data/current/non-infilled/HadCRUT.5.0.1.0.anomalies.ensemble_mean.nc"
)

# %%
prov_plot_url = resp.get()[3]
print(prov_plot_url)
# Out:
# http://localhost:5000/outputs/e4f98d90-ee70-11ed-9768-acde48001122/provenance.png

# %%
from IPython.display import Image
Image(prov_plot_url)
